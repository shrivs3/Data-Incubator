# %% [markdown]
# # Exploring the Chicago crime dataset
# This is the chicago crime dataset on this link - https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2

# %%
import pandas as pd
from bokeh.sampledata.olympics2014 import data
from bokeh.charts import Bar, output_file, show
from bokeh.charts.attributes import cat, color, CatAttr
from bokeh.io import output_notebook
import math

# %%
df=pd.read_csv('Crimes_-_2001_to_present.csv')
df.head()
# Out:
#         ID Case Number                    Date                Block  IUCR  \
# 0  4700982    HM212393  03/03/2006 10:40:00 PM      0000X W 95TH ST  1811
# 1  4700983    HM300030  01/01/2006 12:00:00 PM    049XX S HOYNE AVE  0840
# 2  4700984    HM300880  04/19/2006 09:20:00 PM      0000X W 95TH ST  0460
# 3  4700985    HM304274  04/21/2006 01:45:00 PM     104XX S AVENUE L  1320
# 4  4700986    HM305728  04/22/2006 12:00:00 AM  082XX S PRAIRIE AVE  0910
#
#           Primary Type                    Description  \
# 0            NARCOTICS   POSS: CANNABIS 30GMS OR LESS
# 1                THEFT  FINANCIAL ID THEFT: OVER $300
# 2              BATTERY                         SIMPLE
# 3      CRIMINAL DAMAGE                     TO VEHICLE
# 4  MOTOR VEHICLE THEFT                     AUTOMOBILE
#
#           Location Description  Arrest  Domestic  \
# 0                    CTA TRAIN    True     False
# 1                    RESIDENCE   False     False
# 2  CTA GARAGE / OTHER PROPERTY   False     False
# 3                       STREET   False     False
# 4                       STREET   False     False
#
#                ...                Ward  Community Area  FBI Code  \
# 0              ...                21.0            49.0        18
# 1              ...                16.0            61.0        06
# 2              ...                21.0            49.0       08B
# 3              ...                10.0            52.0        14
# 4              ...                 6.0            44.0        07
#
#    X Coordinate Y Coordinate  Year              Updated On   Latitude  \
# 0     1177762.0    1841949.0  2006  04/15/2016 08:55:02 AM  41.721627
# 1     1163199.0    1871730.0  2006  04/15/2016 08:55:02 AM  41.803667
# 2     1177762.0    1841949.0  2006  04/15/2016 08:55:02 AM  41.721627
# 3     1201838.0    1836252.0  2006  04/15/2016 08:55:02 AM  41.705416
# 4     1179463.0    1850527.0  2006  04/15/2016 08:55:02 AM  41.745128
#
#    Longitude                       Location
# 0 -87.624485  (41.721627204, -87.624485177)
# 1 -87.676995  (41.803667166, -87.676994658)
# 2 -87.624485  (41.721627204, -87.624485177)
# 3 -87.536494   (41.70541635, -87.536493961)
# 4 -87.617994  (41.745127679, -87.617993623)
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Getting attributes
# Firstly I am creating more attributes which I think will be useful in determining the type of crime being commited.

# %%
a=df['Date']
b=[{'date':' ','time':' ', 'ampm':' '} for i in range(len(a))]

# %%
for i in range(len(a)):
    c=a[i].split(' ')
    b[i]['date']=c[0]
    b[i]['time']=c[1]
    b[i]['ampm']=c[2]

# %%
year=[]
month=[]
date=[]
hours=[]
mins=[]
for i in b:
    x=map(int,i['date'].split('/'))
    y=map(int,i['time'].split(':'))
    month.append(x[0])
    date.append(x[1])
    year.append(x[2])
    mins.append(y[1])
    if i['ampm']=='PM':
        if y[0]==12:
            y[0]=0
        hours.append((y[0]+12))
    else:
        hours.append(y[0]%12)

# %%
df['Year']=year
df['Month']=month
df['Date_value']=date
df['Hour']=hours
df['Minutes']=mins

# %%
df=pd.read_csv('chicago_updated.csv')

# %%
crime_count={i:0 for i in set(df['Primary Type'])}
year_count={i:0 for i in set(df['Year'])}
time_count={i:0 for i in set(df['Hour'])}
location= {i:0 for i in set(df['Location Description'])}

# %%
for i in range(len(df)):
    crime_count[df.loc[i, 'Primary Type']]+=1
    year_count[df.loc[i,'Year']]+=1
    time_count[df.loc[i,'Hour']]+=1
    location[df.loc[i,'Location Description']]+=1

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a7a42dbd-ad45-4f24-8985-799c24304be9">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Data Exploration
# Exploration of the trends in the data.
# 1. Location Descriptions where the most crime reportings have taken place.
# 2. Types of crimes which have been most reported.
# 3. Yearly trend of crime reporting
# 4. Hour-wise rate of crime.

# %%
a=[]
b=[]
for i in location.keys():
    if type(i) is float:
        continue
    else:
        a.append(i)
        b.append(location[i])
        
df1=pd.DataFrame()
df1['location']=a
df1['count']=b
df1=df1.sort_values(by='count', ascending=False)
df1=df1[0:20]
df1

p = Bar(df1, label=CatAttr(columns=['location'], sort=False), values='count',title="Crime count by location",  color="red")

output_file("locationCount.html")
p.legend.visible=False

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b72e9fb2-3801-4e16-bbd4-123efb8aff48"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b72e9fb2-3801-4e16-bbd4-123efb8aff48");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b72e9fb2-3801-4e16-bbd4-123efb8aff48");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b72e9fb2-3801-4e16-bbd4-123efb8aff48' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"287de7c5-877d-414e-a1c1-d0b7a078d638":{"roots":{"references":[{"attributes":{"label":{"value":"COMMERCIAL / BUSINESS OFFICE"},"renderers":[{"id":"3b5c5e5c-391e-407d-8370-6d06f03263da","type":"GlyphRenderer"}]},"id":"7a66fd36-2757-4c95-800b-5449c9eecc1d","type":"LegendItem"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ebb11aed-a52a-491b-9252-566c5471dcde","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"location":"CHA PARKING LOT/GROUNDS"}],"color":["red"],"fill_alpha":[0.8],"height":[109836.0],"label":[{"location":"CHA PARKING LOT/GROUNDS"}],"line_alpha":[1.0],"line_color":["white"],"location":["CHA PARKING LOT/GROUNDS"],"width":[0.8],"x":["CHA PARKING LOT/GROUNDS"],"y":[54918.0]}},"id":"bbd63a6a-7bab-4eba-b8c8-143f723a6342","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"b602ba29-dd50-40ad-9085-b7c810c82512","type":"ColumnDataSource"},"glyph":{"id":"3c3982bd-1b10-44af-ba95-15d18d37006e","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"b35581b0-5fb2-4a0f-9a01-186cda9f5bd4","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"a93f5bfc-b2c2-4222-94c5-c3595d6f2195","type":"ColumnDataSource"},"glyph":{"id":"06213cca-edae-4986-9431-a99fdc2f8892","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"d718f9ff-884b-46d1-acda-5af6227f4ab9","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"59d74b7f-f6f5-411d-bbff-54af62dabe5a","subtype":"Chart","type":"Plot"}},"id":"cbe16324-f39d-4c82-81d0-e36455189356","type":"HelpTool"},{"attributes":{"data_source":{"id":"cffc4415-14ee-465e-bc92-78f8779bcd13","type":"ColumnDataSource"},"glyph":{"id":"09e81583-3b2f-45e0-8af4-7429dd07f88d","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"b8f06305-4647-4468-b298-8567c543436f","type":"GlyphRenderer"},{"attributes":{"axis_label":"Sum( Count )","formatter":{"id":"1c9075f2-c490-4dd8-a68f-8ddf91f10a8e","type":"BasicTickFormatter"},"plot":{"id":"59d74b7f-f6f5-411d-bbff-54af62dabe5a","subtype":"Chart","type":"Plot"},"ticker":{"id":"de10825a-68b0-4750-9ca0-fd9be7b684fa","type":"BasicTicker"}},"id":"7a37b85f-a7f4-4fb8-ae38-c60d2199f663","type":"LinearAxis"},{"attributes":{"label":{"value":"RESIDENCE"},"renderers":[{"id":"aeb969e9-49b7-47f0-9cde-2d2054077944","type":"GlyphRenderer"}]},"id":"3346e622-5d6d-4bb1-afd5-18855512136b","type":"LegendItem"},{"attributes":{"data_source":{"id":"8cd5dbeb-89d7-49ab-bd71-bad2586c6c4b","type":"ColumnDataSource"},"glyph":{"id":"415072ee-68fe-4fa9-9d0f-e2019dcb13fc","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"c798531e-9667-4798-a0d2-c6dc7c44a4b5","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"59d74b7f-f6f5-411d-bbff-54af62dabe5a","subtype":"Chart","type":"Plot"},"ticker":{"id":"de10825a-68b0-4750-9ca0-fd9be7b684fa","type":"BasicTicker"}},"id":"5b11d226-e66f-4116-ad2c-ad3027dff1cb","type":"Grid"},{"attributes":{"data_source":{"id":"644d237a-d773-402c-a963-860104f96bed","type":"ColumnDataSource"},"glyph":{"id":"f0d7bc70-ce29-4fde-be1a-e27fc3447571","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"2342c787-5f0b-426c-9004-95ac18060946","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"d6e85676-5eb6-4e38-824d-b9dab51d9633","type":"ColumnDataSource"},"glyph":{"id":"8108be64-1e71-48c7-8383-0de54a5987b0","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"30ce80e7-ee46-47d7-ac1b-f0e9a0f6fe38","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"792e4817-57b6-44f0-95bf ...

# %%
a=[]
b=[]
for i in crime_count.keys():
    if type(i) is float:
        continue
    else:
        a.append(i)
        b.append(crime_count[i])
        
df1=pd.DataFrame()
df1['type']=a
df1['count']=b
df1=df1.sort_values(by='count', ascending=False)
df1=df1[0:20]


p = Bar(df1, label=CatAttr(columns=['type'], sort=False), values='count',title="Crime count by Type",  color="wheat")

output_file("locationCount.html")
p.legend.visible=False

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3c2b65f6-85ed-4f05-9784-2b06d5d803dd"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("3c2b65f6-85ed-4f05-9784-2b06d5d803dd");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3c2b65f6-85ed-4f05-9784-2b06d5d803dd");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3c2b65f6-85ed-4f05-9784-2b06d5d803dd' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"60c12298-785d-4d06-9c76-a673298eb212":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c9725c5b-b8e3-4e1a-b437-1fa280fc4003","type":"Rect"},{"attributes":{},"id":"3869acd9-07ed-435e-862f-19d806d26420","type":"CategoricalTicker"},{"attributes":{"data_source":{"id":"0fef125a-5c4b-4b18-8d0a-25a7442152ae","type":"ColumnDataSource"},"glyph":{"id":"64dd1b15-42ab-48b2-8237-20673d9a4499","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"38a64317-97bf-4511-a994-7dd5b5d0e088","type":"GlyphRenderer"},{"attributes":{"label":{"value":"WEAPONS VIOLATION"},"renderers":[{"id":"f28e2843-8f28-4d75-8273-72cd78ddb50b","type":"GlyphRenderer"}]},"id":"50023998-3851-4aad-b7d2-0cb3a617549a","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"type":"PUBLIC PEACE VIOLATION"}],"color":["wheat"],"fill_alpha":[0.8],"height":[92760.0],"label":[{"type":"PUBLIC PEACE VIOLATION"}],"line_alpha":[1.0],"line_color":["white"],"type":["PUBLIC PEACE VIOLATION"],"width":[0.8],"x":["PUBLIC PEACE VIOLATION"],"y":[46380.0]}},"id":"c3c37a11-beda-4f38-9e54-83f8a99a6f9d","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"f0bae07d-830f-4134-ada2-591e7155fca1","type":"ColumnDataSource"},"glyph":{"id":"c7cb9a11-3a86-4626-a69a-078b1e66715b","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"10d28bb3-c103-4f08-8267-8da34d2d042e","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"type":"LIQUOR LAW VIOLATION"}],"color":["wheat"],"fill_alpha":[0.8],"height":[27584.0],"label":[{"type":"LIQUOR LAW VIOLATION"}],"line_alpha":[1.0],"line_color":["white"],"type":["LIQUOR LAW VIOLATION"],"width":[0.8],"x":["LIQUOR LAW VIOLATION"],"y":[13792.0]}},"id":"6ce07cc9-4217-44cd-880c-d0f91cd74e37","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0383a82e-37b6-4aa0-bf02-bdc13252ac00","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b0d21404-2168-43f3-853a-ad7ab3a10a4d","type":"Rect"},{"attributes":{},"id":"262b0ab4-a614-4ddc-b977-6668a6a5eb6c","type":"BasicTicker"},{"attributes":{"callback":null,"factors":["THEFT","BATTERY","CRIMINAL DAMAGE","NARCOTICS","OTHER OFFENSE","ASSAULT","BURGLARY","MOTOR VEHICLE THEFT","ROBBERY","DECEPTIVE PRACTICE","CRIMINAL TRESPASS","PROSTITUTION","WEAPONS VIOLATION","PUBLIC PEACE VIOLATION","OFFENSE INVOLVING CHILDREN","CRIM SEXUAL ASSAULT","SEX OFFENSE","GAMBLING","INTERFERENCE WITH PUBLIC OFFICER","LIQUOR LAW VIOLATION"]},"id":"6636468a-0069-4d8c-bec8-37c74b9610fc","type":"FactorRange"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"type":"OFFENSE INVOLVING CHILDREN"}],"color":["wheat"],"fill_alpha":[0.8],"height":[85284.0],"label":[{"type":"OFFENSE INVOLVING CHILDREN"}],"line_alpha":[1.0],"line_color":["white"],"type":["OFFENSE INVOLVING CHILDREN"],"width":[0.8],"x":["OFFENSE INVOLVING CHILDREN"],"y":[42642.0]}},"id":"0fef125a-5c4b-4b18-8d0a-25a7442152ae","type":"ColumnDataSource"},{"attributes":{},"id":"74889bd2-f5c1-451a-a028-23853deb5a06","type":"CategoricalTickFormatter"},{"attributes":{"fill_alpha":{"field":"fi ...

# %%
a=[]
b=[]
for i in year_count.keys():
    if type(i) is float:
        continue
    else:
        a.append(i)
        b.append(year_count[i])
        
df1=pd.DataFrame()
df1['year']=a
df1['count']=b
df1=df1.sort_values(by='count', ascending=False)


p = Bar(df1, label=CatAttr(columns=['year'], sort=False), values='count',title="Crime count by Year",  color="SaddleBrown")

output_file("locationCount.html")
p.legend.visible=False

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="bf12adf8-dabb-48de-9964-4848bc97a78b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("bf12adf8-dabb-48de-9964-4848bc97a78b");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("bf12adf8-dabb-48de-9964-4848bc97a78b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'bf12adf8-dabb-48de-9964-4848bc97a78b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"24a975cc-4052-47d3-b22a-790b4b2634dc":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"year":2006}],"color":["SaddleBrown"],"fill_alpha":[0.8],"height":[896132.0],"label":[{"year":2006}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["2006"],"y":[448066.0],"year":[2006]}},"id":"b3cb1202-ad8b-4d5f-9d57-84eaec3fcbe6","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6f6330e5-5764-404e-a2a8-eb7fa902209f","type":"Rect"},{"attributes":{"label":{"value":"2014"},"renderers":[{"id":"368b24f6-dd22-4b36-8fb6-fa3d2811e339","type":"GlyphRenderer"}]},"id":"4e89c713-e984-4a6f-9139-58bfa2b4fa80","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"year":2007}],"color":["SaddleBrown"],"fill_alpha":[0.8],"height":[873926.0],"label":[{"year":2007}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["2007"],"y":[436963.0],"year":[2007]}},"id":"faea1599-cb54-4a97-8eca-de2f8b99b709","type":"ColumnDataSource"},{"attributes":{"label":{"value":"2001"},"renderers":[{"id":"661e57e2-905b-411c-aaa0-c582e6ab2c67","type":"GlyphRenderer"}]},"id":"b5271856-c272-4fef-ad53-2863ad9bd146","type":"LegendItem"},{"attributes":{"label":{"value":"2003"},"renderers":[{"id":"f2925e28-1593-4f60-aa6d-e6780ce9cd4a","type":"GlyphRenderer"}]},"id":"a05c846c-4273-42bb-bbd2-dc5ef93458ca","type":"LegendItem"},{"attributes":{"label":{"value":"2010"},"renderers":[{"id":"c881dcea-1587-472b-b417-f1dd5b79c26b","type":"GlyphRenderer"}]},"id":"27d00616-64f6-4435-9297-8237f1443686","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"year":2011}],"color":["SaddleBrown"],"fill_alpha":[0.8],"height":[703292.0],"label":[{"year":2011}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["2011"],"y":[351646.0],"year":[2011]}},"id":"2f6fa728-57e7-467c-b597-00c09b94f2b6","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"20a81265-23ea-4188-92e6-67610db8a5e2","type":"ColumnDataSource"},"glyph":{"id":"ebd3ad97-4c97-4475-b9da-ce21608fd097","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"c881dcea-1587-472b-b417-f1dd5b79c26b","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"year":2008}],"color":["SaddleBrown"],"fill_alpha":[0.8],"height":[853996.0],"label":[{"year":2008}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["2008"],"y":[426998.0],"year":[2008]}},"id":"79e141a9-0d9b-49e6-aca3-0d37954be500","type":"ColumnDataSource"},{"attributes":{},"id":"9f16a534-775e-4c24-a468-6942a3814380","type":"CategoricalTicker"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"year":2009}],"color":["SaddleBrown"],"fill_alpha":[0.8],"height":[785198.0],"label":[{"year":2009}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["2009"],"y":[392599.0],"year":[2009]}},"id":"a921249c-2e5c-4131-b7e5-a28afa06e439","type":"ColumnDataSource"},{"attributes":{"label":{"value":"2004"},"renderers":[{"id":"c4de6c0a-2d8b-4233-a55a-32fc2ff6b90d","type":"GlyphRenderer"}]},"id":"076a902d-8ad9-4028-b12f-15cf1364ff12","type":"LegendItem"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"w ...

# %%
a=[]
b=[]
for i in time_count.keys():
    if type(i) is float:
        continue
    else:
        a.append(i)
        b.append(time_count[i])
        
df1=pd.DataFrame()
df1['hour']=a
df1['count']=b
df1=df1.sort_values(by='count', ascending=False)


p = Bar(df1, label=CatAttr(columns=['hour'], sort=False), values='count',title="Crime count by Hour",  color="GoldenRod")
p.legend.visible=False
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="83dbf5de-c996-4d21-a4fa-b3a30b807c14"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("83dbf5de-c996-4d21-a4fa-b3a30b807c14");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("83dbf5de-c996-4d21-a4fa-b3a30b807c14");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '83dbf5de-c996-4d21-a4fa-b3a30b807c14' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"34c13092-5877-4e8d-968c-1db157190c77":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"hour":12}],"color":["GoldenRod"],"fill_alpha":[0.8],"height":[732927.0],"hour":[12],"label":[{"hour":12}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["12"],"y":[366463.5]}},"id":"6d608286-cbcc-4f48-85d4-a479df51d2ad","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"c7a16716-86c8-4cd5-ad5c-89bb591c1389","type":"ColumnDataSource"},"glyph":{"id":"262f82bd-2623-47d2-b91c-1001456e1a2f","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"bd467c46-88af-4fe3-8862-357366a16368","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"985ee977-62b9-4e63-bc8e-f216f2ab5cc5","subtype":"Chart","type":"Plot"}},"id":"9a662904-8adf-4ac5-9d30-22a3c63b9001","type":"SaveTool"},{"attributes":{"dimension":1,"plot":{"id":"985ee977-62b9-4e63-bc8e-f216f2ab5cc5","subtype":"Chart","type":"Plot"},"ticker":{"id":"44940809-8a74-4b9b-bc2a-927c66f6c8f1","type":"BasicTicker"}},"id":"eac6dd22-c9c2-4137-a38e-e8e488d5bdaf","type":"Grid"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"hour":16}],"color":["GoldenRod"],"fill_alpha":[0.8],"height":[646404.0],"hour":[16],"label":[{"hour":16}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["16"],"y":[323202.0]}},"id":"1dee020d-b28e-4e53-b8b6-2ca3463edb95","type":"ColumnDataSource"},{"attributes":{"label":{"value":"3"},"renderers":[{"id":"8dcfe1b1-c446-44ef-bbcb-49b58718494c","type":"GlyphRenderer"}]},"id":"6d661360-7b66-4d29-84f2-61bbb709efed","type":"LegendItem"},{"attributes":{},"id":"6745b026-cf99-4023-a203-bd10386bdf30","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"99650286-1072-4ab6-a303-31a5c4c80897","type":"ColumnDataSource"},"glyph":{"id":"adf6638e-7126-4886-84d5-8c3d57b48ea6","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"c9cadb42-07e9-4ca9-ad8e-ecd5c55ac23b","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"76037f8a-0e9d-40fd-aa88-91f184e73f79","type":"ColumnDataSource"},"glyph":{"id":"0ed5b4bd-f479-4c0a-9140-e16f8037c63d","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"af017387-6f7e-44b3-813c-1a38b7b2689b","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"28f1004d-b62f-4587-bc83-cbf0d13e37f0","type":"ColumnDataSource"},"glyph":{"id":"bab27bff-4bdb-499d-92c1-8260822b2c4c","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"3750dd2a-6544-4b14-94cf-ff89b5a1bb98","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"hour":5}],"color":["GoldenRod"],"fill_alpha":[0.8],"height":[171900.0],"hour":[5],"label":[{"hour":5}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["5"],"y":[85950.0]}},"id":"c0203081-2795-4f64-b1ed-eb987bca9a5d","type":"ColumnDataSource"},{"attributes":{"label":{"value":"20"},"renderers":[{"id":"0ff16ba0-d288-4d94-ae46-633572b1815a","type":"GlyphRenderer"}]},"id":"3a6874e0-535c-4b00-8e45-561ec3f7358e","type":"LegendItem"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"a8760bdb-a8d1-4894-b584-8e82c0a3f094","type":"PanTool"},{"id":"4b914e95-bcac-41de-a6c5-549bc5f8b6bf","type":"WheelZoomTool"},{"id":"bc2a1a8c-1018-46c4-ac05-26d8c9cc26a4","type":"BoxZoomTool"},{"id":"9a662904-8adf-4ac5-9d30-22a3c63b9001","type":"SaveTool"},{"id":"080ef41c-872d-4c28-a2fb-57ef9840da54","type":"ResetTool"},{"id":"f8a1cefe-6070-455b-97c2-7fbe9c218275","type":"HelpTool"}]},"id":"f456b84a-516b-4ed7-b768-12f0d7004da2","type":"Toolbar"},{"attributes":{"label":{"value":"12"},"renderers":[{"id":"d44c0cad-5bac-4108-b23f-bf038ce2f014","type":"GlyphRenderer"}]},"id":"9019fec0-694d-4ce7 ...
